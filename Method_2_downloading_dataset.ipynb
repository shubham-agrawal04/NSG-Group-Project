# %%
from huggingface_hub import hf_hub_download, login
import os, shutil, numpy as np

# %%
repo_id = "samitizerxu/openfwi"
subfolder = "FlatVel_A"

for prefix in ["data", "model"]:
    for i in range(1, 6):
        fname = f"{subfolder}/{prefix}/{prefix}{i}.npy"
        out_path = os.path.join(subfolder, prefix, f"{prefix}{i}.npy")
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        # download to cache
        cache_path = hf_hub_download(repo_id=repo_id, filename=fname, repo_type="dataset")
        # copy to local folder
        shutil.copy(cache_path, out_path)

# verify existence and load
data_path = os.path.join(subfolder, "data", "data1.npy")
model_path = os.path.join(subfolder, "model", "model1.npy")

print("Exists:", os.path.exists(data_path), os.path.exists(model_path))
data = np.load(data_path)
model = np.load(model_path)
print("Shapes:", data.shape, model.shape)
# Out:
# FlatVel_A/data/data1.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_A/data/data2.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_A/data/data3.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_A/data/data4.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_A/data/data5.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_A/model/model1.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_A/model/model2.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_A/model/model3.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_A/model/model4.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_A/model/model5.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# Exists: True True
# Shapes: (500, 5, 1000, 70) (500, 1, 70, 70)

# %%
repo_id = "samitizerxu/openfwi"
subfolder = "FlatVel_B"

for prefix in ["data", "model"]:
    for i in range(1, 6):
        fname = f"{subfolder}/{prefix}/{prefix}{i}.npy"
        out_path = os.path.join(subfolder, prefix, f"{prefix}{i}.npy")
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        # download to cache
        cache_path = hf_hub_download(repo_id=repo_id, filename=fname, repo_type="dataset")
        # copy to local folder
        shutil.copy(cache_path, out_path)

# verify existence and load
data_path = os.path.join(subfolder, "data", "data1.npy")
model_path = os.path.join(subfolder, "model", "model1.npy")

print("Exists:", os.path.exists(data_path), os.path.exists(model_path))
data = np.load(data_path)
model = np.load(model_path)
print("Shapes:", data.shape, model.shape)
# Out:
# FlatVel_B/data/data1.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_B/data/data2.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_B/data/data3.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_B/data/data4.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_B/data/data5.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# FlatVel_B/model/model1.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_B/model/model2.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_B/model/model3.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_B/model/model4.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# FlatVel_B/model/model5.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# Exists: True True
# Shapes: (500, 5, 1000, 70) (500, 1, 70, 70)

# %%
repo_id = "samitizerxu/openfwi"
subfolder = "CurveVel_A"

for prefix in ["data", "model"]:
    for i in range(1, 6):
        fname = f"{subfolder}/{prefix}/{prefix}{i}.npy"
        out_path = os.path.join(subfolder, prefix, f"{prefix}{i}.npy")
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        # download to cache
        cache_path = hf_hub_download(repo_id=repo_id, filename=fname, repo_type="dataset")
        # copy to local folder
        shutil.copy(cache_path, out_path)

# verify existence and load
data_path = os.path.join(subfolder, "data", "data1.npy")
model_path = os.path.join(subfolder, "model", "model1.npy")

print("Exists:", os.path.exists(data_path), os.path.exists(model_path))
data = np.load(data_path)
model = np.load(model_path)
print("Shapes:", data.shape, model.shape)
# Out:
# CurveVel_A/data/data1.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_A/data/data2.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_A/data/data3.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_A/data/data4.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_A/data/data5.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_A/model/model1.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_A/model/model2.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_A/model/model3.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_A/model/model4.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_A/model/model5.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# Exists: True True
# Shapes: (500, 5, 1000, 70) (500, 1, 70, 70)

# %%
repo_id = "samitizerxu/openfwi"
subfolder = "CurveVel_B"

for prefix in ["data", "model"]:
    for i in range(1, 6):
        fname = f"{subfolder}/{prefix}/{prefix}{i}.npy"
        out_path = os.path.join(subfolder, prefix, f"{prefix}{i}.npy")
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        # download to cache
        cache_path = hf_hub_download(repo_id=repo_id, filename=fname, repo_type="dataset")
        # copy to local folder
        shutil.copy(cache_path, out_path)

# verify existence and load
data_path = os.path.join(subfolder, "data", "data1.npy")
model_path = os.path.join(subfolder, "model", "model1.npy")

print("Exists:", os.path.exists(data_path), os.path.exists(model_path))
data = np.load(data_path)
model = np.load(model_path)
print("Shapes:", data.shape, model.shape)
# Out:
# CurveVel_B/data/data1.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_B/data/data2.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_B/data/data3.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_B/data/data4.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_B/data/data5.npy:   0%|          | 0.00/700M [00:00<?, ?B/s]
# CurveVel_B/model/model1.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_B/model/model2.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_B/model/model3.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_B/model/model4.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# CurveVel_B/model/model5.npy:   0%|          | 0.00/9.80M [00:00<?, ?B/s]
# Exists: True True
# Shapes: (500, 5, 1000, 70) (500, 1, 70, 70)
